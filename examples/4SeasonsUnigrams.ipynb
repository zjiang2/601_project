# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import re
import datetime

# %% [markdown]
# Read in the hashtag list.

# %%
team_hashes = {}
with open('team_hashtags.txt', 'r') as f:
    for line in f:
        words = line.split()
        team = words[0].replace('-', ' ')
        hashes = words[1:]
        team_hashes[team] = hashes

# %% [markdown]
# Code to get all hashtags from a given tweet; function below takes a tweet and a team name (that we want that tweet to only be associated with) and checks if it contains tweets from any other team.

# %%
def get_hashtags(tweet):
    pattern = r'#{1}\w*'
    return re.findall(pattern, tweet)

# %%
def one_team_only(one_tweet, which_team):
    all_teams = team_hashes.copy()
    good = all_teams.pop(which_team)
    temp = [team_hashes[key] for key in all_teams]
    bad_teams = [item for sublist in temp for item in sublist]
    bad_teams = set(bad_teams)
    curr_hashes = set(get_hashtags(one_tweet))
    
    if len(list(curr_hashes & bad_teams)) != 0:
            return False
    return True

# %% [markdown]
# Read in the data for a full season, and convert the type of the datetime column.

# %%
s1 = pd.read_csv('2020_all_data.csv', index_col=0)
s2 = pd.read_csv('2019_all_data.csv', index_col=0)
s3 = pd.read_csv('2018_all_data.csv', index_col=0)
s4 = pd.read_csv('2017_all_data.csv', index_col=0)
full = pd.concat([s4,s3,s2,s1],axis=0)
full['Datetime'] = pd.DatetimeIndex(full['Datetime'], tz='US/Eastern')
full['Datetime'] = full['Datetime'].dt.tz_convert('UTC')
full['Home'] = np.where(full['Home'] == 'Washington Redskins', 'Washington Football Team', full['Home'])
full['Away'] = np.where(full['Away'] == 'Washington Redskins', 'Washington Football Team', full['Away'])
full['Home'] = np.where(full['Home'] == 'San Diego Chargers', 'Los Angeles Chargers', full['Home'])
full['Away'] = np.where(full['Away'] == 'San Diego Chargers', 'Los Angeles Chargers', full['Away'])
full['Home'] = np.where(full['Home'] == 'St Louis Rams', 'Los Angeles Rams', full['Home'])
full['Away'] = np.where(full['Away'] == 'St Louis Rams', 'Los Angeles Rams', full['Away'])
full['Home'] = np.where(full['Home'] == 'Oakland Raiders', 'Las Vegas Raiders', full['Home'])
full['Away'] = np.where(full['Away'] == 'Oakland Raiders', 'Las Vegas Raiders', full['Away'])

# %%
full
# Out:
#            Date    Time                  Datetime                      Home  \
# 0    2017-09-07  8:30PM 2017-09-08 00:30:00+00:00      New England Patriots
# 1    2017-09-10  1:00PM 2017-09-10 17:00:00+00:00             Chicago Bears
# 2    2017-09-10  1:00PM 2017-09-10 17:00:00+00:00             Buffalo Bills
# 3    2017-09-10  1:00PM 2017-09-10 17:00:00+00:00          Tennessee Titans
# 4    2017-09-10  1:00PM 2017-09-10 17:00:00+00:00  Washington Football Team
# ..          ...     ...                       ...                       ...
# 251  2021-01-03  4:25PM 2021-01-03 21:25:00+00:00             Chicago Bears
# 252  2021-01-03  4:25PM 2021-01-03 21:25:00+00:00        Kansas City Chiefs
# 253  2021-01-03  4:25PM 2021-01-03 21:25:00+00:00            Denver Broncos
# 254  2021-01-03  4:25PM 2021-01-03 21:25:00+00:00            Houston Texans
# 255  2021-01-03  8:20PM 2021-01-04 01:20:00+00:00       Philadelphia Eagles
#
#                          Away  Home Win
# 0          Kansas City Chiefs         0
# 1             Atlanta Falcons         0
# 2               New York Jets         1
# 3           Las Vegas Raiders         0
# 4         Philadelphia Eagles         0
# ..                        ...       ...
# 251         Green Bay Packers         0
# 252      Los Angeles Chargers         0
# 253         Las Vegas Raiders         0
# 254          Tennessee Titans         0
# 255  Washington Football Team         0
#
# [1024 rows x 6 columns]

# %% [markdown]
# Initialize containers. Home_tweets contains all tweets related to the home teams, same for away, and corpus contains all the unique words seen.

# %%
home_tweets = []
away_tweets = []
corpus = {}

# %%
# count unigrams
def count_unigrams(tweet):
    global corpus
    words = tweet.split(" ")
    for word in words:
        if word in corpus:
            corpus[word] += 1
        else:
            corpus[word] = 1

# %% [markdown]
# Returns all valid tweets for one game, for one team. A valid tweet is one which is between the desired start and end times; has at least 10 likes; and only contains hashtags related to one team.

# %%
def one_game_one_team(game_time, team_name):
    start = game_time - datetime.timedelta(days=1,hours=1)
    end = game_time - datetime.timedelta(hours=1)
    date_range = " since:" + start.strftime('%Y-%m-%d') + " until:" + end.strftime('%Y-%m-%d')
    
    team_tags = " OR ".join(team_hashes[team_name])
    query = team_tags + date_range
    
    # Scrape the tweets for the date_range. Also have to filter based on the 
    # time stamp so as not to capture tweets during and after games.
    to_return = []
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
        if i > 10000:
            break
        if not (start <= tweet.date and tweet.date <= end):
            continue
        if tweet.likeCount < 10:
            continue
        if not one_team_only(tweet.content.lower(), team_name):
            continue
        tw = tweet.content.lower()
        to_return.append(tw)
        count_unigrams(tw)
    return to_return

# %% [markdown]
# Gets all tweets for an entire season. Uses the above helper function to get a

# %%
def get_season_tweets(df):
    for game in range(len(df)):
        print("Processing game number {}".format(game))
        gametime = df.iloc[game]['Datetime']
        hometeam = df.iloc[game]['Home']
        awayteam = df.iloc[game]['Away']
        
        h_tweets = one_game_one_team(gametime, hometeam)
        a_tweets = one_game_one_team(gametime, awayteam)
        
        home_tweets.append(h_tweets)
        away_tweets.append(a_tweets)
        
    return

# %%
get_season_tweets(full)
# Out:
# Processing game number 0
# Processing game number 1
# Processing game number 2
# Processing game number 3
# Processing game number 4
# Processing game number 5
# Processing game number 6
# Processing game number 7
# Processing game number 8
# Processing game number 9
# Processing game number 10
# Processing game number 11
# Processing game number 12
# Processing game number 13
# Processing game number 14
# Processing game number 15
# Processing game number 16
# Processing game number 17
# Processing game number 18
# Processing game number 19
# Processing game number 20
# Processing game number 21
# Processing game number 22
# Processing game number 23
# Processing game number 24
# Processing game number 25
# Processing game number 26
# Processing game number 27
# Processing game number 28
# Processing game number 29
# Processing game number 30
# Processing game number 31
# Processing game number 32
# Processing game number 33
# Processing game number 34
# Processing game number 35
# Processing game number 36
# Processing game number 37
# Processing game number 38
# Processing game number 39
# Processing game number 40
# Processing game number 41
# Processing game number 42
# Processing game number 43
# Processing game number 44
# Processing game number 45
# Processing game number 46
# Processing game number 47
# Processing game number 48
# Processing game number 49
# Processing game number 50
# Processing game number 51
# Processing game number 52
# Processing game number 53
# Processing game number 54
# Processing game number 55
# Processing game number 56
# Processing game number 57
# Processing game number 58
# Processing game number 59
# Processing game number 60
# Processing game number 61
# Processing game number 62
# Processing game number 63
# Processing game number 64
# Processing game number 65
# Processing game number 66
# Processing game number 67
# Processing game number 68
# Processing game number 69
# Processing game number 70
# Processing game number 71
# Processing game number 72
# Processing game number 73
# Processing game number 74
# Processing game number 75
# Processing game number 76
# Processing game number 77
# Processing game number 78
# Processing game number 79
# Processing game number 80
# Processing game number 81
# Processing game number 82
# Processing game number 83
# Processing game number 84
# Processing game number 85
# Processing game number 86
# Processing game number 87
# Processing game number 88
# Processing game number 89
# Processing game number 90
# Processing game number 91
# Processing game number 92
# Processing game number 93
# Processing game number 94
# Processing game number 95
# Processing game number 96
# Processing game number 97
# Processing game number 98
# Processing game number 99
# Processing game number 100
# Processing game number 101
# Processing game number 102
# Processing game number 103
# Processing game number 104
# Processing game number 105
# Processing game number 106
# Processing game number 107
# Processing game number 108
# Processing game number 109
# Processing game number 110
# Processing game number 111
# Processing game number 112
# Processing game number 113
# Processing game number 114
# Processing game number 115
# Processing game number 116
# Processing game number 117
# Processing game number 118
# Processing game number 119
# Processing game number 120
# Processing game number 121
# Processing game number 122
# Processing game number 123
# Processing game number 124
# Processing game number 125
# Processing game number 126
# Processing game number 127
# Processing game number 128
# Processing game number 129
# Processing game number 130
# Processing game number 131
# Processing game number 132
# Processing game number 133
# Processing game number 134
# Processing game number 135
# Processing game number 136
# Processing game number 137
# Processing game number 138
# Processing game number 139
# Processing game number 140
# Processing game number 141
# Processing game number 142
# Processing game number 143
# Processing game number 144
# Processing game number 145
# Processing game number 146
# Processing game number 147
# Processing game number 148
# Processing game number 149
# Processing game number 150
# Processing game number 151
# Processing game number 152
# Processing game number 153
# Processing game number 154
# Processing game number 155
# Processing game number 156
# Processing game number 157
# Processing game number 158
# Processing game number 159
# Processing game number 160
# Processing game number 161
# Processing game number 162
# Processing game number 163
# Processing game number 164
# Processing game number 165
# Processing game number 166
# Processing game number 167
# Processing game number 168
# Processing game number 169
# Processing game number 170
# Processing game number 171
# Processing game number 172
# Processing game number 173
# Processing game number 174
# Processing game number 175
# Processing game number 176
# Processing game number 177
# Processing game number 178
# Processing game number 179
# Processing game number 180
# Processing game number 181
# Processing game number 182
# Processing game number 183
# Processing game number 184
# Processing game number 185
# Processing game number 186
# Processing game number 187
# Processing game number 188
# Processing game number 189
# Processing game number 190
# Processing game number 191
# Processing game number 192
# Processing game number 193
# Processing game number 194
# Processing game number 195
# Processing game number 196
# Processing game number 197
# Processing game number 198
# Processing game number 199
# Processing game number 200
# Processing game number 201
# Processing game number 202
# Processing game number 203
# Processing game number 204
# Processing game number 205
# Processing game number 206
# Processing game number 207
# Processing game number 208
# Processing game number 209
# Processing game number 210
# Processing game number 211
# Processing game number 212
# Processing game number 213
# Processing game number 214
# Processing game number 215
# Processing game number 216
# Processing game number 217
# Processing game number 218
# Processing game number 219
# Processing game number 220
# Processing game number 221
# Processing game number 222
# Processing game number 223
# Processing game number 224
# Processing game number 225
# Processing game number 226
# Processing game number 227
# Processing game number 228
# Processing game number 229
# Processing game number 230
# Processing game number 231
# Processing game number 232
# Processing game number 233
# Processing game number 234
# Processing game number 235
# Processing game number 236
# Processing game number 237
# Processing game number 238
# Processing game number 239
# Processing game number 240
# Processing game number 241
# Processing game number 242
# Processing game number 243
# Processing game number 244
# Processing game number 245
# Processing game number 246
# Processing game number 247
# Processing game number 248
# Processing game number 249
# Processing game number 250
# Processing game number 251
# Processing game number 252
# Processing game number 253
# Processing game number 254
# Processing game number 255
# Processing game number 256
# Processing game number 257
# Processing game number 258
# Processing game number 259
# Processing game number 260
# Processing game number 261
# Processing game number 262
# Processing game number 263
# Processing game number 264
# Processing game number 265
# Processing game number 266
# Processing game number 267
# Processing game number 268
# Processing game number 269
# Processing game number 270
# Processing game number 271
# Processing game number 272
# Processing game number 273
# Processing game number 274
# Processing game number 275
# Processing game number 276
# Processing game number 277
# Processing game number 278
# Processing game number 279
# Processing game number 280
# Processing game number 281
# Processing game number 282
# Processing game number 283
# Processing game number 284
# Processing game number 285
# Processing game number 286
# Processing game number 287
# Processing game number 288
# Processing game number 289
# Processing game number 290
# Processing game number 291
# Processing game number 292
# Processing game number 293
# Processing game number 294
# Processing game number 295
# Processing game number 296
# Processing game number 297
# Processing game number 298
# Processing game number 299
# Processing game number 300
# Processing game number 301
# Processing game number 302
# Processing game number 303
# Processing game number 304
# Processing game number 305
# Processing game number 306
# Processing game number 307
# Processing game number 308
# Processing game number 309
# Processing game number 310
# Processing game number 311
# Processing game number 312
# Processing game number 313
# Processing game number 314
# Processing game number 315
# Processing game number 316
# Processing game number 317
# Processing game number 318
# Processing game number 319
# Processing game number 320
# Processing game number 321
# Processing game number 322
# Processing game number 323
# Processing game number 324
# Processing game number 325
# Processing game number 326
# Processing game number 327
# Processing game number 328
# Processing game number 329
# Processing game number 330
# Processing game number 331
# Processing game number 332
# Processing game number 333
# Processing game number 334
# Processing game number 335
# Processing game number 336
# Processing game number 337
# Processing game number 338
# Processing game number 339
# Processing game number 340
# Processing game number 341
# Processing game number 342
# Processing game number 343
# Processing game number 344
# Processing game number 345
# Processing game number 346
# Processing game number 347
# Processing game number 348
# Processing game number 349
# Processing game number 350
# Processing game number 351
# Processing game number 352
# Processing game number 353
# Processing game number 354
# Processing game number 355
# Processing game number 356
# Processing game number 357
# Processing game number 358
# Processing game number 359
# Processing game number 360
# Processing game number 361
# Processing game number 362
# Processing game number 363
# Processing game number 364
# Processing game number 365
# Processing game number 366
# Processing game number 367
# Processing game number 368
# Processing game number 369
# Processing game number 370
# Processing game number 371
# Processing game number 372
# Processing game number 373
# Processing game number 374
# Processing game number 375
# Processing game number 376
# Processing game number 377
# Processing game number 378
# Processing game number 379
# Processing game number 380
# Processing game number 381
# Processing game number 382
# Processing game number 383
# Processing game number 384
# Processing game number 385
# Processing game number 386
# Processing game number 387
# Processing game number 388
# Processing game number 389
# Processing game number 390
# Processing game number 391
# Processing game number 392
# Processing game number 393
# Processing game number 394
# Processing game number 395
# Processing game number 396
# Processing game number 397
# Processing game number 398
# Processing game number 399
# Processing game number 400
# Processing game number 401
# Processing game number 402
# Processing game number 403
# Processing game number 404
# Processing game number 405
# Processing game number 406
# Processing game number 407
# Processing game number 408
# Processing game number 409
# Processing game number 410
# Processing game number 411
# Processing game number 412
# Processing game number 413
# Processing game number 414
# Processing game number 415
# Processing game number 416
# Processing game number 417
# Processing game number 418
# Processing game number 419
# Processing game number 420
# Processing game number 421
# Processing game number 422
# Processing game number 423
# Processing game number 424
# Processing game number 425
# Processing game number 426
# Processing game number 427
# Processing game number 428
# Processing game number 429
# Processing game number 430
# Processing game number 431
# Processing game number 432
# Processing game number 433
# Processing game number 434
# Processing game number 435
# Processing game number 436
# Processing game number 437
# Processing game number 438
# Processing game number 439
# Processing game number 440
# Processing game number 441
# Processing game number 442
# Processing game number 443
# Processing game number 444
# Processing game number 445
# Processing game number 446
# Processing game number 447
# Processing game number 448
# Processing game number 449
# Processing game number 450
# Processing game number 451
# Processing game number 452
# Processing game number 453
# Processing game number 454
# Processing game number 455
# Processing game number 456
# Processing game number 457
# Processing game number 458
# Processing game number 459
# Processing game number 460
# Processing game number 461
# Processing game number 462
# Processing game number 463
# Processing game number 464
# Processing game number 465
# Processing game number 466
# Processing game number 467
# Processing game number 468
# Processing game number 469
# Processing game number 470
# Processing game number 471
# Processing game number 472
# Processing game number 473
# Processing game number 474
# Processing game number 475
# Processing game number 476
# Processing game number 477
# Processing game number 478
# Processing game number 479
# Processing game number 480
# Processing game number 481
# Processing game number 482
# Processing game number 483
# Processing game number 484
# Processing game number 485
# Processing game number 486
# Processing game number 487
# Processing game number 488
# Processing game number 489
# Processing game number 490
# Processing game number 491
# Processing game number 492
# Processing game number 493
# Processing game number 494
# Processing game number 495
# Processing game number 496
# Processing game number 497
# Processing game number 498
# Processing game number 499
# Processing game number 500
# Processing game number 501
# Processing game number 502
# Processing game number 503
# Processing game number 504
# Processing game number 505
# Processing game number 506
# Processing game number 507
# Processing game number 508
# Processing game number 509
# Processing game number 510
# Processing game number 511
# Processing game number 512
# Processing game number 513
# Processing game number 514
# Processing game number 515
# Processing game number 516
# Processing game number 517
# Processing game number 518
# Processing game number 519
# Processing game number 520
# Processing game number 521
# Processing game number 522
# Processing game number 523
# Processing game number 524
# Processing game number 525
# Processing game number 526
# Processing game number 527
# Processing game number 528
# Processing game number 529
# Processing game number 530
# Processing game number 531
# Processing game number 532
# Processing game number 533
# Processing game number 534
# Processing game number 535
# Processing game number 536
# Processing game number 537
# Processing game number 538
# Processing game number 539
# Processing game number 540
# Processing game number 541
# Processing game number 542
# Processing game number 543
# Processing game number 544
# Processing game number 545
# Processing game number 546
# Processing game number 547
# Processing game number 548
# Processing game number 549
# Processing game number 550
# Processing game number 551
# Processing game number 552
# Processing game number 553
# Processing game number 554
# Processing game number 555
# Processing game number 556
# Processing game number 557
# Processing game number 558
# Processing game number 559
# Processing game number 560
# Processing game number 561
# Processing game number 562
# Processing game number 563
# Processing game number 564
# Processing game number 565
# Processing game number 566
# Processing game number 567
# Processing game number 568
# Processing game number 569
# Processing game number 570
# Processing game number 571
# Processing game number 572
# Processing game number 573
# Processing game number 574
# Processing game number 575
# Processing game number 576
# Processing game number 577
# Processing game number 578
# Processing game number 579
# Processing game number 580
# Processing game number 581
# Processing game number 582
# Processing game number 583
# Processing game number 584
# Processing game number 585
# Processing game number 586
# Processing game number 587
# Processing game number 588
# Processing game number 589
# Processing game number 590
# Processing game number 591
# Processing game number 592
# Processing game number 593
# Processing game number 594
# Processing game number 595
# Processing game number 596
# Processing game number 597
# Processing game number 598
# Processing game number 599
# Processing game number 600
# Processing game number 601
# Processing game number 602
# Processing game number 603
# Processing game number 604
# Processing game number 605
# Processing game number 606
# Processing game number 607
# Processing game number 608
# Processing game number 609
# Processing game number 610
# Processing game number 611
# Processing game number 612
# Processing game number 613
# Processing game number 614
# Processing game number 615
# Processing game number 616
# Processing game number 617
# Processing game number 618
# Processing game number 619
# Processing game number 620
# Processing game number 621
# Processing game number 622
# Processing game number 623
# Processing game number 624
# Processing game number 625
# Processing game number 626
# Processing game number 627
# Processing game number 628
# Processing game number 629
# Processing game number 630
# Processing game number 631
# Processing game number 632
# Processing game number 633
# Processing game number 634
# Processing game number 635
# Processing game number 636
# Processing game number 637
# Processing game number 638
# Processing game number 639
# Processing game number 640
# Processing game number 641
# Processing game number 642
# Processing game number 643
# Processing game number 644
# Processing game number 645
# Processing game number 646
# Processing game number 647
# Processing game number 648
# Processing game number 649
# Processing game number 650
# Processing game number 651
# Processing game number 652
# Processing game number 653
# Processing game number 654
# Processing game number 655
# Processing game number 656
# Processing game number 657
# Processing game number 658
# Processing game number 659
# Processing game number 660
# Processing game number 661
# Processing game number 662
# Processing game number 663
# Processing game number 664
# Processing game number 665
# Processing game number 666
# Processing game number 667
# Processing game number 668
# Processing game number 669
# Processing game number 670
# Processing game number 671
# Processing game number 672
# Processing game number 673
# Processing game number 674
# Processing game number 675
# Processing game number 676
# Processing game number 677
# Processing game number 678
# Processing game number 679
# Processing game number 680
# Processing game number 681
# Processing game number 682
# Processing game number 683
# Processing game number 684
# Processing game number 685
# Processing game number 686
# Processing game number 687
# Processing game number 688
# Processing game number 689
# Processing game number 690
# Processing game number 691
# Processing game number 692
# Processing game number 693
# Processing game number 694
# Processing game number 695
# Processing game number 696
# Processing game number 697
# Processing game number 698
# Processing game number 699
# Processing game number 700
# Processing game number 701
# Processing game number 702
# Processing game number 703
# Processing game number 704
# Processing game number 705
# Processing game number 706
# Processing game number 707
# Processing game number 708
# Processing game number 709
# Processing game number 710
# Processing game number 711
# Processing game number 712
# Processing game number 713
# Processing game number 714
# Processing game number 715
# Processing game number 716
# Processing game number 717
# Processing game number 718
# Processing game number 719
# Processing game number 720
# Processing game number 721
# Processing game number 722
# Processing game number 723
# Processing game number 724
# Processing game number 725
# Processing game number 726
# Processing game number 727
# Processing game number 728
# Processing game number 729
# Processing game number 730
# Processing game number 731
# Processing game number 732
# Processing game number 733
# Processing game number 734
# Processing game number 735
# Processing game number 736
# Processing game number 737
# Processing game number 738
# Processing game number 739
# Processing game number 740
# Processing game number 741
# Processing game number 742
# Processing game number 743
# Processing game number 744
# Processing game number 745
# Processing game number 746
# Processing game number 747
# Processing game number 748
# Processing game number 749
# Processing game number 750
# Processing game number 751
# Processing game number 752
# Processing game number 753
# Processing game number 754
# Processing game number 755
# Processing game number 756
# Processing game number 757
# Processing game number 758
# Processing game number 759
# Processing game number 760
# Processing game number 761
# Processing game number 762
# Processing game number 763
# Processing game number 764
# Processing game number 765
# Processing game number 766
# Processing game number 767
# Processing game number 768
# Processing game number 769
# Processing game number 770
# Processing game number 771
# Processing game number 772
# Processing game number 773
# Processing game number 774
# Processing game number 775
# Processing game number 776
# Processing game number 777
# Processing game number 778
# Processing game number 779
# Processing game number 780
# Processing game number 781
# Processing game number 782
# Processing game number 783
# Processing game number 784
# Processing game number 785
# Processing game number 786
# Processing game number 787
# Processing game number 788
# Processing game number 789
# Processing game number 790
# Processing game number 791
# Processing game number 792
# Processing game number 793
# Processing game number 794
# Processing game number 795
# Processing game number 796
# Processing game number 797
# Processing game number 798
# Processing game number 799
# Processing game number 800
# Processing game number 801
# Processing game number 802
# Processing game number 803
# Processing game number 804
# Processing game number 805
# Processing game number 806
# Processing game number 807
# Processing game number 808
# Processing game number 809
# Processing game number 810
# Processing game number 811
# Processing game number 812
# Processing game number 813
# Processing game number 814
# Processing game number 815
# Processing game number 816
# Processing game number 817
# Processing game number 818
# Processing game number 819
# Processing game number 820
# Processing game number 821
# Processing game number 822
# Processing game number 823
# Processing game number 824
# Processing game number 825
# Processing game number 826
# Processing game number 827
# Processing game number 828
# Processing game number 829
# Processing game number 830
# Processing game number 831
# Processing game number 832
# Processing game number 833
# Processing game number 834
# Processing game number 835
# Processing game number 836
# Processing game number 837
# Processing game number 838
# Processing game number 839
# Processing game number 840
# Processing game number 841
# Processing game number 842
# Processing game number 843
# Processing game number 844
# Processing game number 845
# Processing game number 846
# Processing game number 847
# Processing game number 848
# Processing game number 849
# Processing game number 850
# Processing game number 851
# Processing game number 852
# Processing game number 853
# Processing game number 854
# Processing game number 855
# Processing game number 856
# Processing game number 857
# Processing game number 858
# Processing game number 859
# Processing game number 860
# Processing game number 861
# Processing game number 862
# Processing game number 863
# Processing game number 864
# Processing game number 865
# Processing game number 866
# Processing game number 867
# Processing game number 868
# Processing game number 869
# Processing game number 870
# Processing game number 871
# Processing game number 872
# Processing game number 873
# Processing game number 874
# Processing game number 875
# Processing game number 876
# Processing game number 877
# Processing game number 878
# Processing game number 879
# Processing game number 880
# Processing game number 881
# Processing game number 882
# Processing game number 883
# Processing game number 884
# Processing game number 885
# Processing game number 886
# Processing game number 887
# Processing game number 888
# Processing game number 889
# Processing game number 890
# Processing game number 891
# Processing game number 892
# Processing game number 893
# Processing game number 894
# Processing game number 895
# Processing game number 896
# Processing game number 897
# Processing game number 898
# Processing game number 899
# Processing game number 900
# Processing game number 901
# Processing game number 902
# Processing game number 903
# Processing game number 904
# Processing game number 905
# Processing game number 906
# Processing game number 907
# Processing game number 908
# Processing game number 909
# Processing game number 910
# Processing game number 911
# Processing game number 912
# Processing game number 913
# Processing game number 914
# Processing game number 915
# Processing game number 916
# Processing game number 917
# Processing game number 918
# Processing game number 919
# Processing game number 920
# Processing game number 921
# Processing game number 922
# Processing game number 923
# Processing game number 924
# Processing game number 925
# Processing game number 926
# Processing game number 927
# Processing game number 928
# Processing game number 929
# Processing game number 930
# Processing game number 931
# Processing game number 932
# Processing game number 933
# Processing game number 934
# Processing game number 935
# Processing game number 936
# Processing game number 937
# Processing game number 938
# Processing game number 939
# Processing game number 940
# Processing game number 941
# Processing game number 942
# Processing game number 943
# Processing game number 944
# Processing game number 945
# Processing game number 946
# Processing game number 947
# Processing game number 948
# Processing game number 949
# Processing game number 950
# Processing game number 951
# Processing game number 952
# Processing game number 953
# Processing game number 954
# Processing game number 955
# Processing game number 956
# Processing game number 957
# Processing game number 958
# Processing game number 959
# Processing game number 960
# Processing game number 961
# Processing game number 962
# Processing game number 963
# Processing game number 964
# Processing game number 965
# Processing game number 966
# Processing game number 967
# Processing game number 968
# Processing game number 969
# Processing game number 970
# Processing game number 971
# Processing game number 972
# Processing game number 973
# Processing game number 974
# Processing game number 975
# Processing game number 976
# Processing game number 977
# Processing game number 978
# Processing game number 979
# Processing game number 980
# Processing game number 981
# Processing game number 982
# Processing game number 983
# Processing game number 984
# Processing game number 985
# Processing game number 986
# Processing game number 987
# Processing game number 988
# Processing game number 989
# Processing game number 990
# Processing game number 991
# Processing game number 992
# Processing game number 993
# Processing game number 994
# Processing game number 995
# Processing game number 996
# Processing game number 997
# Processing game number 998
# Processing game number 999
# Processing game number 1000
# Processing game number 1001
# Processing game number 1002
# Processing game number 1003
# Processing game number 1004
# Processing game number 1005
# Processing game number 1006
# Processing game number 1007
# Processing game number 1008
# Processing game number 1009
# Processing game number 1010
# Processing game number 1011
# Processing game number 1012
# Processing game number 1013
# Processing game number 1014
# Processing game number 1015
# Processing game number 1016
# Processing game number 1017
# Processing game number 1018
# Processing game number 1019
# Processing game number 1020
# Processing game number 1021
# Processing game number 1022
# Processing game number 1023

# %%
import pickle
with open('data/pickled_tweets_corpus/4seasons_home_unigrams.pkl', 'wb') as f:
    pickle.dump(home_tweets, f)
with open('data/pickled_tweets_corpus/4seasons_away_unigrams.pkl', 'wb') as f:
    pickle.dump(away_tweets, f)
with open('data/pickled_tweets_corpus/4seasons_corpus_unigrams.pkl', 'wb') as f:
    pickle.dump(corpus, f)

# %% [markdown]
# Delete words with less than 2 letters or less from the corpus.

# %%
revised_corpus = corpus.copy()
for key in list(revised_corpus.keys()):
    if len(key) <= 2:
        del revised_corpus[key]

# %% [markdown]
# Get the top 100 or more unigrams by frequency. Call this our corpus (can be changed)

# %%
top_grams = [x[0] for x in sorted(revised_corpus.items(), key=lambda x: x[1], reverse=True)[:1000]]

# %% [markdown]
# A function that, given a list of (valid) tweets for one game and a corpus of interest, returns a numerical version representation of the game. Each number in the return vector represents one word in the corpus, and it is computed as the number of occurrences of that word in tweets about this game, divided by the total number of tweets about this game.

# %%
from collections import Counter
def vectorize_list(list_of_tweets, corpus):
    num_tweets = len(list_of_tweets)
    lol = [x.split() for x in list_of_tweets]
    with_repeats = [item for sublist in lol for item in sublist]
    counts = dict(Counter(with_repeats))
    to_return = []
    for key in corpus:
        num = counts[key]/num_tweets if key in counts else 0
        to_return.append(num)
    return to_return

# %%
vectorize_list(home_tweets[0], ['the', 'and', 'for','this'])
# Out:
# [0.75, 0, 0.625, 0.125]

# %% [markdown]
# Vectorize each home and each away game.

# %%
num_h_tweets = [vectorize_list(game, top_grams) for game in home_tweets]
num_a_tweets = [vectorize_list(game, top_grams) for game in away_tweets]

# %% [markdown]
# Concatenate the home and away vectors as in the papers, and use this to produce our X and Y to perform models on.

# %%
home_vecs = np.array(num_h_tweets)
away_vecs = np.array(num_a_tweets)
X = np.concatenate([home_vecs, away_vecs], axis=1)

# %%
Y = full.iloc[:,-1].values

# %%
X.shape
# Out:
# (1024, 2000)

# %%
Y.shape
# Out:
# (1024,)

# %%
np.save('data/preprocessed/X_1000_uni_no2_4seasons', X)
np.save('data/preprocessed/Y_2000_uni_no2_4seasons', Y)

# %%
#everything = np.concatenate([X,Y.reshape(-1,1)], axis=1)
#np.random.shuffle(everything)
#xs = everything[:,:-1]
#ys = everything[:,-1]
X_train = X[:768]
X_test = X[768:]
Y_train = Y[:768]
Y_test = Y[768:]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, Y_train)
lr.score(X_test, Y_test)
# Out:
# 0.53515625

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=1000)
ada.fit(X_train, Y_train)
ada.score(X_test, Y_test)
# Out:
# 0.46875

# %%
ada.score(X_train, Y_train)
# Out:
# 0.9986979166666666

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier().fit(X_train, Y_train)
dt.score(X_test, Y_test)
dt.score(X_test, Y_test)
# Out:
# 0.5

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, Y_train)
rf.score(X_test, Y_test)
# Out:
# 0.51953125

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=1000)
mlp.fit(X_train, Y_train)
mlp.score(X_test, Y_test)
# Out:
# 0.51953125

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, Y_train)
gnb.score(X_test, Y_test)
# Out:
# 0.53515625
